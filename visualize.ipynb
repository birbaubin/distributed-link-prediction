# %%
import pandas as pd
import matplotlib.pyplot as plt


baseline_logs = pd.read_csv("logs/baseline.csv")
new_protocol_logs = pd.read_csv("logs/new.csv")

plt.plot(baseline_logs, label="Baseline")
plt.plot(new_protocol_logs, label="New protocol")
plt.legend()
# new_protocol_logs.plot()
